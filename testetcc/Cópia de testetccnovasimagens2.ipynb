# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from PIL import Image
# # erro no 70 114 116 127
# for x in range(0 , 110):
#   c = x+1
#   im = Image.open('/content/drive/MyDrive/tentativa2/dataset_treino/hel/h ('+f'{c}'+').jpg')
#   im_resized = im.resize((128, 128))
#   im_resized.save('/content/drive/MyDrive/tentativa3/treino/hel/h.'+f'{c}'+'.jpg')
#   c = 0

# %%
# from PIL import Image

# for x in range(1 , 110):
#   c = x+1
#   im = Image.open('/content/drive/MyDrive/tentativa2/dataset_treino/pro/p ('+f'{c}'+').jpg')
#   im_resized = im.resize((128, 128))
#   im_resized.save('/content/drive/MyDrive/tentativa3/treino/pro/p.'+f'{c}'+'.jpg')
#   c = 0

# %%
#  from PIL import Image
#  for x in range(0 , 30):
#    c = x+1
#    im = Image.open('/content/drive/MyDrive/tentativa2/dataset_validacao/pro/p ('+f'{c}'+').jpg')
#    im_resized = im.resize((128, 128))
#    im_resized.save('/content/drive/MyDrive/tentativa3/validacao/pro/p.'+f'{c}'+'.jpg')
#    c = 0

# %%
#  from PIL import Image

#  for x in range(0 , 30):
#    c = x+1
#    im = Image.open('/content/drive/MyDrive/tentativa2/dataset_validacao/hel/h ('+f'{c}'+').jpg')
#    im_resized = im.resize((128, 128))
#    im_resized.save('/content/drive/MyDrive/tentativa3/validacao/hel/h.'+f'{c}'+'.jpg')
#    c = 0

# %%
  # from PIL import Image

  # for x in range(0 , 23):
  #   c = x+1
  #   im = Image.open('/content/drive/MyDrive/tentativa2/dataset_teste/p ('+f'{c}'+').jpg')
  #   im_resized = im.resize((128, 128))
  #   im_resized.save('/content/drive/MyDrive/tentativa3/teste/p.'+f'{c}'+'.jpg')
  #   c = 0

# %%
from PIL import Image
Lista_n = []
for x in range(0, 110):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/treino/pro/p.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 30):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/validacao/pro/p.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 23):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/teste/p.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 110):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/treino/hel/h.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 30):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/validacao/hel/h.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 19):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/teste/h.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
# Imports
import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
# Inicializando a Rede Neural Convolucional
classifier = Sequential()
classifier.add(Conv2D(X, (X,X), input_shape = (128, 128, X), activation = 'relu'))

# %%
# Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %%
# A Segunda Camada de Convolução
classifier.add(Conv2D(X, (X,X), activation = 'relu'))

# %%
# Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %%
# Passo 3 - Flattening
classifier.add(Flatten())

# %%
# Passo 4 - Full connection
classifier.add(Dense(units = X, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
# Compilando a rede
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])

# %%
# Criando os objetos train_datagen e validation_datagen com as regras de pré-processamento das imagens
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Pré-processamento das imagens de treino e validação
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/tentativa3/treino',
                                                 target_size = (128, 128),
                                                 batch_size = 30,
                                                 #color_mode='grayscale',
                                                 class_mode = 'binary')

validation_set = validation_datagen.flow_from_directory('/content/drive/MyDrive/tentativa3/validacao',
                                                        target_size = (128, 128),
                                                        batch_size = 30,
                                                        #color_mode='grayscale',
                                                        class_mode = 'binary')
# Out:
# Found 222 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
classifier.fit(training_set, epochs = 100, validation_data = validation_set, validation_steps = 30)
# Out:
# Epoch 1/100
# 8/8 [==============================] - ETA: 0s - loss: 7.7704 - accuracy: 0.4505 - mse: 0.4590
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 30 batches). You may need to use the repeat() function when building your dataset.
# 8/8 [==============================] - 49s 6s/step - loss: 7.7704 - accuracy: 0.4505 - mse: 0.4590 - val_loss: 1.0277 - val_accuracy: 0.5000 - val_mse: 0.3547
# Epoch 2/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.8088 - accuracy: 0.4685 - mse: 0.2943
# Epoch 3/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.6375 - accuracy: 0.5495 - mse: 0.2249
# Epoch 4/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.6023 - accuracy: 0.6802 - mse: 0.2115
# Epoch 5/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.5652 - accuracy: 0.7523 - mse: 0.1907
# Epoch 6/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.4970 - accuracy: 0.7838 - mse: 0.1665
# Epoch 7/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.4322 - accuracy: 0.8153 - mse: 0.1426
# Epoch 8/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.3676 - accuracy: 0.8378 - mse: 0.1119
# Epoch 9/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.3571 - accuracy: 0.8378 - mse: 0.1101
# Epoch 10/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.3425 - accuracy: 0.8243 - mse: 0.1100
# Epoch 11/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.3241 - accuracy: 0.8288 - mse: 0.1044
# Epoch 12/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.2919 - accuracy: 0.8604 - mse: 0.0912
# Epoch 13/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.2478 - accuracy: 0.8874 - mse: 0.0773
# Epoch 14/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.1796 - accuracy: 0.9324 - mse: 0.0527
# Epoch 15/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.1631 - accuracy: 0.9324 - mse: 0.0479
# Epoch 16/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.1700 - accuracy: 0.9550 - mse: 0.0390
# Epoch 17/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.1784 - accuracy: 0.9369 - mse: 0.0490
# Epoch 18/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.1483 - accuracy: 0.9550 - mse: 0.0420
# Epoch 19/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.1136 - accuracy: 0.9595 - mse: 0.0330
# Epoch 20/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0664 - accuracy: 0.9775 - mse: 0.0177
# Epoch 21/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0407 - accuracy: 0.9910 - mse: 0.0097
# Epoch 22/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0340 - accuracy: 0.9865 - mse: 0.0078
# Epoch 23/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0184 - accuracy: 1.0000 - mse: 0.0022
# Epoch 24/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0550 - accuracy: 0.9820 - mse: 0.0135
# Epoch 25/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0327 - accuracy: 0.9910 - mse: 0.0065
# Epoch 26/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0816 - accuracy: 0.9775 - mse: 0.0169
# Epoch 27/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0662 - accuracy: 0.9775 - mse: 0.0177
# Epoch 28/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0532 - accuracy: 0.9865 - mse: 0.0128
# Epoch 29/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0505 - accuracy: 0.9865 - mse: 0.0126
# Epoch 30/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0508 - accuracy: 0.9865 - mse: 0.0119
# Epoch 31/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0936 - accuracy: 0.9865 - mse: 0.0154
# Epoch 32/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0673 - accuracy: 0.9820 - mse: 0.0156
# Epoch 33/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0547 - accuracy: 0.9865 - mse: 0.0144
# Epoch 34/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0384 - accuracy: 0.9910 - mse: 0.0096
# Epoch 35/100
# 8/8 [==============================] - 25s 3s/step - loss: 0.0256 - accuracy: 0.9910 - mse: 0.0059
# Epoch 36/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0236 - accuracy: 0.9955 - mse: 0.0054
# Epoch 37/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0137 - accuracy: 1.0000 - mse: 0.0017
# Epoch 38/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0072 - accuracy: 1.0000 - mse: 4.0147e-04
# Epoch 39/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0120 - accuracy: 0.9910 - mse: 0.0035
# Epoch 40/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0107 - accuracy: 0.9955 - mse: 0.0024
# Epoch 41/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0265 - accuracy: 0.9955 - mse: 0.0055
# Epoch 42/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0152 - accuracy: 0.9955 - mse: 0.0039
# Epoch 43/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0071 - accuracy: 1.0000 - mse: 0.0013
# Epoch 44/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0151 - accuracy: 0.9955 - mse: 0.0040
# Epoch 45/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0682 - accuracy: 0.9640 - mse: 0.0216
# Epoch 46/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0406 - accuracy: 0.9910 - mse: 0.0091
# Epoch 47/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0206 - accuracy: 0.9955 - mse: 0.0041
# Epoch 48/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0339 - accuracy: 0.9955 - mse: 0.0080
# Epoch 49/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.1189 - accuracy: 0.9775 - mse: 0.0220
# Epoch 50/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0420 - accuracy: 0.9865 - mse: 0.0117
# Epoch 51/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0544 - accuracy: 0.9865 - mse: 0.0136
# Epoch 52/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0330 - accuracy: 0.9910 - mse: 0.0076
# Epoch 53/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0097 - accuracy: 1.0000 - mse: 9.2381e-04
# Epoch 54/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0066 - accuracy: 1.0000 - mse: 8.7490e-04
# Epoch 55/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0068 - accuracy: 0.9955 - mse: 0.0015
# Epoch 56/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0043 - accuracy: 1.0000 - mse: 5.9769e-04
# Epoch 57/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0027 - accuracy: 1.0000 - mse: 2.6663e-04
# Epoch 58/100
# 8/8 [==============================] - 25s 3s/step - loss: 0.0013 - accuracy: 1.0000 - mse: 2.6054e-05
# Epoch 59/100
# 8/8 [==============================] - 26s 3s/step - loss: 0.0018 - accuracy: 1.0000 - mse: 9.8339e-05
# Epoch 60/100
# 8/8 [==============================] - 26s 3s/step - loss: 9.8672e-04 - accuracy: 1.0000 - mse: 2.5730e-05
# Epoch 61/100
# 8/8 [==============================] - 26s 3s/step - loss: 6.2079e-04 - accuracy: 1.0000 - mse: 7.4596e-06
# Epoch 62/100
# 8/8 [==============================] - 26s 3s/step - loss: 4.0542e-04 - accuracy: 1.0000 - mse: 2.6229e-06
# Epoch 63/100
# 8/8 [==============================] - 26s 3s/step - loss: 3.5674e-04 - accuracy: 1.0000 - mse: 1.5338e-06
# Epoch 64/100
# 8/8 [==============================] - 26s 3s/step - loss: 3.1073e-04 - accuracy: 1.0000 - mse: 1.4236e-06
# Epoch 65/100
# 8/8 [==============================] - 26s 3s/step - loss: 3.4979e-04 - accuracy: 1.0000 - mse: 1.4025e-06
# Epoch 66/100
# 8/8 [==============================] - 26s 3s/step - loss: 3.1978e-04 - accuracy: 1.0000 - mse: 1.1112e-06
# Epoch 67/100
# 8/8 [==============================] - 26s 3s/step - loss: 2.6169e-04 - accuracy: 1.0000 - mse: 7.0706e-07
# Epoch 68/100
# 8/8 [==============================] - 26s 3s/step - loss: 2.2347e-04 - accuracy: 1.0000 - mse: 5.4450e-07
# Epoch 69/100
# 8/8 [==============================] - 26s 3s/step - loss: 2.6528e-04 - accuracy: 1.0000 - mse: 8.9565e-07
# Epoch 70/100
# 8/8 [==============================] - 26s 3s/step - loss: 2.1727e-04 - accuracy: 1.0000 - mse: 7.4188e-07
# Epoch 71/100
# 8/8 [==============================] - 26s 3s/step - loss: 2.0583e-04 - accuracy: 1.0000 - mse: 5.6499e-07
# Epoch 72/100
# 8/8 [==============================] - 26s 3s/step - loss: 2.0377e-04 - accuracy: 1.0000 - mse: 6.4276e-07
# Epoch 73/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.7283e-04 - accuracy: 1.0000 - mse: 4.4911e-07
# Epoch 74/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.5741e-04 - accuracy: 1.0000 - mse: 2.6183e-07
# Epoch 75/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.7228e-04 - accuracy: 1.0000 - mse: 4.6248e-07
# Epoch 76/100
# 8/8 [==============================] - 25s 3s/step - loss: 1.8309e-04 - accuracy: 1.0000 - mse: 4.3196e-07
# Epoch 77/100
# 8/8 [==============================] - 25s 3s/step - loss: 1.8182e-04 - accuracy: 1.0000 - mse: 3.9092e-07
# Epoch 78/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.3207e-04 - accuracy: 1.0000 - mse: 1.8044e-07
# Epoch 79/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.3877e-04 - accuracy: 1.0000 - mse: 2.2562e-07
# Epoch 80/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.6109e-04 - accuracy: 1.0000 - mse: 3.3337e-07
# Epoch 81/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.2093e-04 - accuracy: 1.0000 - mse: 1.7564e-07
# Epoch 82/100
# 8/8 [==============================] - 27s 3s/step - loss: 1.2098e-04 - accuracy: 1.0000 - mse: 1.9951e-07
# Epoch 83/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.4099e-04 - accuracy: 1.0000 - mse: 2.3661e-07
# Epoch 84/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.1237e-04 - accuracy: 1.0000 - mse: 1.4584e-07
# Epoch 85/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.4182e-04 - accuracy: 1.0000 - mse: 2.2242e-07
# Epoch 86/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.3395e-04 - accuracy: 1.0000 - mse: 2.0187e-07
# Epoch 87/100
# 8/8 [==============================] - 26s 3s/step - loss: 9.2273e-05 - accuracy: 1.0000 - mse: 1.1522e-07
# Epoch 88/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.0647e-04 - accuracy: 1.0000 - mse: 1.3152e-07
# Epoch 89/100
# 8/8 [==============================] - 26s 3s/step - loss: 8.5923e-05 - accuracy: 1.0000 - mse: 8.9057e-08
# Epoch 90/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.1430e-04 - accuracy: 1.0000 - mse: 1.4520e-07
# Epoch 91/100
# 8/8 [==============================] - 25s 3s/step - loss: 9.4335e-05 - accuracy: 1.0000 - mse: 8.3766e-08
# Epoch 92/100
# 8/8 [==============================] - 26s 3s/step - loss: 9.8522e-05 - accuracy: 1.0000 - mse: 8.9538e-08
# Epoch 93/100
# 8/8 [==============================] - 26s 3s/step - loss: 1.0015e-04 - accuracy: 1.0000 - mse: 1.1851e-07
# Epoch 94/100
# 8/8 [==============================] - 26s 3s/step - loss: 9.9330e-05 - accuracy: 1.0000 - mse: 1.0811e-07
# Epoch 95/100
# 8/8 [==============================] - 26s 3s/step - loss: 9.1423e-05 - accuracy: 1.0000 - mse: 8.4612e-08
# Epoch 96/100
# 8/8 [==============================] - 25s 3s/step - loss: 9.2379e-05 - accuracy: 1.0000 - mse: 9.7335e-08
# Epoch 97/100
# 8/8 [==============================] - 26s 3s/step - loss: 8.3921e-05 - accuracy: 1.0000 - mse: 7.7914e-08
# Epoch 98/100
# 8/8 [==============================] - 26s 3s/step - loss: 7.6020e-05 - accuracy: 1.0000 - mse: 6.1643e-08
# Epoch 99/100
# 8/8 [==============================] - 26s 3s/step - loss: 8.5261e-05 - accuracy: 1.0000 - mse: 7.6849e-08
# Epoch 100/100
# 8/8 [==============================] - 26s 3s/step - loss: 6.9262e-05 - accuracy: 1.0000 - mse: 4.6438e-08

# %%
import numpy as np
import keras.utils as image

test_image = image.load_img('/content/drive/MyDrive/tentativa3/teste/h.6.jpg', target_size = (128, 128, 3))#, color_mode='grayscale')
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
training_set.class_indices

if result[0][0] == 1:
    prediction = 'Protozoario'
else:
    prediction = 'Helminto'

from IPython.display import Image

Image(filename='/content/drive/MyDrive/tentativa3/teste/h.6.jpg')

# %%
prediction
# Out:
# 'Protozoario'

# %%
import numpy as np
import keras.utils as image
import time
for x in range(0, 18):
  test_image = image.load_img('/content/drive/MyDrive/tentativa3/teste/h.'+f'{x+1}'+'.jpg', target_size = (128, 128, A))#, color_mode='grayscale')
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis = 0)
  result = classifier.predict(test_image)
  training_set.class_indices

  if result[0][0] == 1:
      prediction = 'Protozoario'
  else:
      prediction = 'Helminto'
  time.sleep(1)
  print(f'{x+1}'+f' - {prediction}')
for x in range(0, 23):
  test_image = image.load_img('/content/drive/MyDrive/tentativa3/teste/p.'+f'{x+1}'+'.jpg', target_size = (128, 128, A))#, color_mode='grayscale')
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis = 0)
  result = classifier.predict(test_image)
  training_set.class_indices
  if result[0][0] == 1:
      prediction = 'Protozoario'
  else:
      prediction = 'Helminto'
  time.sleep(1)
  print(f'{x+1}'+f' - {prediction}')
# Out:
# 1/1 [==============================] - 0s 167ms/step
# 1 - Helminto
# 1/1 [==============================] - 0s 86ms/step
# 2 - Helminto
# 1/1 [==============================] - 0s 80ms/step
# 3 - Helminto
# 1/1 [==============================] - 0s 82ms/step
# 4 - Helminto
# 1/1 [==============================] - 0s 83ms/step
# 5 - Helminto
# 1/1 [==============================] - 0s 86ms/step
# 6 - Helminto
# 1/1 [==============================] - 0s 82ms/step
# 7 - Protozoario
# 1/1 [==============================] - 0s 82ms/step
# 8 - Protozoario
# 1/1 [==============================] - 0s 81ms/step
# 9 - Helminto
# 1/1 [==============================] - 0s 81ms/step
# 10 - Helminto
# 1/1 [==============================] - 0s 83ms/step
# 11 - Protozoario
# 1/1 [==============================] - 0s 81ms/step
# 12 - Helminto
# 1/1 [==============================] - 0s 82ms/step
# 13 - Protozoario
# 1/1 [==============================] - 0s 79ms/step
# 14 - Helminto
# 1/1 [==============================] - 0s 79ms/step
# 15 - Helminto
# 1/1 [==============================] - 0s 82ms/step
# 16 - Helminto
# 1/1 [==============================] - 0s 79ms/step
# 17 - Helminto
# 1/1 [==============================] - 0s 80ms/step
# 18 - Helminto
# 1/1 [==============================] - 0s 82ms/step
# 1 - Protozoario
# 1/1 [==============================] - 0s 82ms/step
# 2 - Helminto
# 1/1 [==============================] - 0s 80ms/step
# 3 - Protozoario
# 1/1 [==============================] - 0s 80ms/step
# 4 - Protozoario
# 1/1 [==============================] - 0s 81ms/step
# 5 - Helminto
# 1/1 [==============================] - 0s 84ms/step
# 6 - Protozoario
# 1/1 [==============================] - 0s 85ms/step
# 7 - Helminto
# 1/1 [==============================] - 0s 81ms/step
# 8 - Helminto
# 1/1 [==============================] - 0s 81ms/step
# 9 - Helminto
# 1/1 [==============================] - 0s 80ms/step
# 10 - Helminto
# 1/1 [==============================] - 0s 83ms/step
# 11 - Helminto
# 1/1 [==============================] - 0s 81ms/step
# 12 - Helminto
# 1/1 [==============================] - 0s 85ms/step
# 13 - Protozoario
# 1/1 [==============================] - 0s 85ms/step
# 14 - Protozoario
# 1/1 [==============================] - 0s 82ms/step
# 15 - Protozoario
# 1/1 [==============================] - 0s 82ms/step
# 16 - Protozoario
# 1/1 [==============================] - 0s 81ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-cdce7304ed7d> in <module>
#      25   else:
#      26       prediction = 'Helminto'
# ---> 27   time.sleep(1)
#      28   print(f'{x+1}'+f' - {prediction}')
#
# KeyboardInterrupt:
