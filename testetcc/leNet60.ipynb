# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from PIL import Image
# # erro no 70 114 116 127
# for x in range(0 , 110):
#   c = x+1
#   im = Image.open('/content/drive/MyDrive/tentativa2/dataset_treino/hel/h ('+f'{c}'+').jpg')
#   im_resized = im.resize((128, 128))
#   im_resized.save('/content/drive/MyDrive/tentativa3/treino/hel/h.'+f'{c}'+'.jpg')
#   c = 0

# %%
# from PIL import Image

# for x in range(1 , 110):
#   c = x+1
#   im = Image.open('/content/drive/MyDrive/tentativa2/dataset_treino/pro/p ('+f'{c}'+').jpg')
#   im_resized = im.resize((128, 128))
#   im_resized.save('/content/drive/MyDrive/tentativa3/treino/pro/p.'+f'{c}'+'.jpg')
#   c = 0

# %%
#  from PIL import Image
#  for x in range(0 , 30):
#    c = x+1
#    im = Image.open('/content/drive/MyDrive/tentativa2/dataset_validacao/pro/p ('+f'{c}'+').jpg')
#    im_resized = im.resize((128, 128))
#    im_resized.save('/content/drive/MyDrive/tentativa3/validacao/pro/p.'+f'{c}'+'.jpg')
#    c = 0

# %%
#  from PIL import Image

#  for x in range(0 , 30):
#    c = x+1
#    im = Image.open('/content/drive/MyDrive/tentativa2/dataset_validacao/hel/h ('+f'{c}'+').jpg')
#    im_resized = im.resize((128, 128))
#    im_resized.save('/content/drive/MyDrive/tentativa3/validacao/hel/h.'+f'{c}'+'.jpg')
#    c = 0

# %%
  # from PIL import Image

  # for x in range(0 , 23):
  #   c = x+1
  #   im = Image.open('/content/drive/MyDrive/tentativa2/dataset_teste/p ('+f'{c}'+').jpg')
  #   im_resized = im.resize((128, 128))
  #   im_resized.save('/content/drive/MyDrive/tentativa3/teste/p.'+f'{c}'+'.jpg')
  #   c = 0

# %%
from PIL import Image
Lista_n = []
for x in range(0, 110):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/treino/pro/p.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 30):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/validacao/pro/p.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 23):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/teste/p.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 110):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/treino/hel/h.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 30):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/validacao/hel/h.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
from PIL import Image
Lista_n = []
for x in range(0, 19):
  c = x+1
  image = Image.open('/content/drive/MyDrive/tentativa3/teste/h.'+f'{c}'+'.jpg')
  Lista_n.append(image.size)
  c=0
print(Lista_n)
# Out:
# [(128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128), (128, 128)]

# %%
# Imports
import tensorflow
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
# Inicializando a Rede Neural Convolucional
# print(help(keras.layers.Conv2D))
classifier = Sequential()
classifier.add(Conv2D(32, (5,5), input_shape = (128, 128, 3), activation = 'relu'))

# %%
# Passo 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %%
# Adicionando a Segunda Camada de Convolução
classifier.add(Conv2D(64, (2,2), activation = 'relu'))

# %%
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %%
# Passo 3 - Flattening
classifier.add(Flatten())

# %%
# Passo 4 - Full connection
classifier.add(Dense(units = 256, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
# Compilando a rede
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])

# %%
# Criando os objetos train_datagen e validation_datagen com as regras de pré-processamento das imagens
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                    # shear_range = 0.2,
                                    # zoom_range = 0.2,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Pré-processamento das imagens de treino e validação
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/tentativa3/treino',
                                                 target_size = (128, 128),
                                                 batch_size = 30,
                                                 #color_mode='grayscale',
                                                 class_mode = 'binary')

validation_set = validation_datagen.flow_from_directory('/content/drive/MyDrive/tentativa3/validacao',
                                                        target_size = (128, 128),
                                                        batch_size = 30,
                                                        #color_mode='grayscale',
                                                        class_mode = 'binary')
# Out:
# Found 222 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
classifier.fit(training_set, epochs = 60, validation_data = validation_set, validation_steps = 30)
# Out:
# Epoch 1/60
# 8/8 [==============================] - ETA: 0s - loss: 2.3291 - accuracy: 0.5045 - mse: 0.3502
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 30 batches). You may need to use the repeat() function when building your dataset.
# 8/8 [==============================] - 8s 905ms/step - loss: 2.3291 - accuracy: 0.5045 - mse: 0.3502 - val_loss: 0.7033 - val_accuracy: 0.4833 - val_mse: 0.2550
# Epoch 2/60
# 8/8 [==============================] - 6s 695ms/step - loss: 0.6892 - accuracy: 0.5541 - mse: 0.2480
# Epoch 3/60
# 8/8 [==============================] - 6s 681ms/step - loss: 0.6854 - accuracy: 0.5766 - mse: 0.2462
# Epoch 4/60
# 8/8 [==============================] - 6s 730ms/step - loss: 0.6506 - accuracy: 0.5901 - mse: 0.2300
# Epoch 5/60
# 8/8 [==============================] - 6s 714ms/step - loss: 0.6520 - accuracy: 0.6171 - mse: 0.2306
# Epoch 6/60
# 8/8 [==============================] - 6s 731ms/step - loss: 0.6433 - accuracy: 0.6216 - mse: 0.2267
# Epoch 7/60
# 8/8 [==============================] - 6s 678ms/step - loss: 0.6421 - accuracy: 0.6486 - mse: 0.2250
# Epoch 8/60
# 8/8 [==============================] - 6s 671ms/step - loss: 0.6252 - accuracy: 0.6036 - mse: 0.2197
# Epoch 9/60
# 8/8 [==============================] - 6s 672ms/step - loss: 0.5906 - accuracy: 0.6667 - mse: 0.2046
# Epoch 10/60
# 8/8 [==============================] - 6s 668ms/step - loss: 0.5557 - accuracy: 0.7072 - mse: 0.1899
# Epoch 11/60
# 8/8 [==============================] - 6s 686ms/step - loss: 0.5635 - accuracy: 0.7252 - mse: 0.1917
# Epoch 12/60
# 8/8 [==============================] - 6s 690ms/step - loss: 0.5313 - accuracy: 0.7342 - mse: 0.1780
# Epoch 13/60
# 8/8 [==============================] - 6s 734ms/step - loss: 0.5432 - accuracy: 0.7297 - mse: 0.1847
# Epoch 14/60
# 8/8 [==============================] - 6s 676ms/step - loss: 0.4596 - accuracy: 0.8063 - mse: 0.1499
# Epoch 15/60
# 8/8 [==============================] - 6s 684ms/step - loss: 0.4312 - accuracy: 0.8108 - mse: 0.1382
# Epoch 16/60
# 8/8 [==============================] - 6s 678ms/step - loss: 0.4216 - accuracy: 0.8153 - mse: 0.1373
# Epoch 17/60
# 8/8 [==============================] - 6s 683ms/step - loss: 0.4321 - accuracy: 0.7658 - mse: 0.1424
# Epoch 18/60
# 8/8 [==============================] - 6s 681ms/step - loss: 0.3969 - accuracy: 0.8198 - mse: 0.1241
# Epoch 19/60
# 8/8 [==============================] - 6s 715ms/step - loss: 0.3380 - accuracy: 0.8694 - mse: 0.1052
# Epoch 20/60
# 8/8 [==============================] - 6s 679ms/step - loss: 0.3313 - accuracy: 0.8694 - mse: 0.1029
# Epoch 21/60
# 8/8 [==============================] - 6s 680ms/step - loss: 0.2686 - accuracy: 0.8739 - mse: 0.0817
# Epoch 22/60
# 8/8 [==============================] - 6s 681ms/step - loss: 0.2440 - accuracy: 0.9054 - mse: 0.0708
# Epoch 23/60
# 8/8 [==============================] - 6s 694ms/step - loss: 0.2191 - accuracy: 0.9144 - mse: 0.0646
# Epoch 24/60
# 8/8 [==============================] - 6s 688ms/step - loss: 0.1737 - accuracy: 0.9595 - mse: 0.0454
# Epoch 25/60
# 8/8 [==============================] - 6s 775ms/step - loss: 0.1795 - accuracy: 0.9324 - mse: 0.0511
# Epoch 26/60
# 8/8 [==============================] - 6s 693ms/step - loss: 0.1729 - accuracy: 0.9459 - mse: 0.0452
# Epoch 27/60
# 8/8 [==============================] - 6s 687ms/step - loss: 0.1797 - accuracy: 0.9279 - mse: 0.0523
# Epoch 28/60
# 8/8 [==============================] - 6s 772ms/step - loss: 0.1629 - accuracy: 0.9459 - mse: 0.0455
# Epoch 29/60
# 8/8 [==============================] - 6s 681ms/step - loss: 0.1336 - accuracy: 0.9505 - mse: 0.0376
# Epoch 30/60
# 8/8 [==============================] - 6s 687ms/step - loss: 0.1286 - accuracy: 0.9640 - mse: 0.0333
# Epoch 31/60
# 8/8 [==============================] - 6s 689ms/step - loss: 0.0993 - accuracy: 0.9730 - mse: 0.0260
# Epoch 32/60
# 8/8 [==============================] - 6s 692ms/step - loss: 0.0871 - accuracy: 0.9685 - mse: 0.0235
# Epoch 33/60
# 8/8 [==============================] - 6s 736ms/step - loss: 0.0861 - accuracy: 0.9910 - mse: 0.0205
# Epoch 34/60
# 8/8 [==============================] - 6s 690ms/step - loss: 0.0683 - accuracy: 0.9910 - mse: 0.0150
# Epoch 35/60
# 8/8 [==============================] - 6s 684ms/step - loss: 0.0733 - accuracy: 0.9820 - mse: 0.0185
# Epoch 36/60
# 8/8 [==============================] - 6s 687ms/step - loss: 0.0634 - accuracy: 0.9820 - mse: 0.0155
# Epoch 37/60
# 8/8 [==============================] - 6s 682ms/step - loss: 0.0569 - accuracy: 0.9775 - mse: 0.0129
# Epoch 38/60
# 8/8 [==============================] - 6s 683ms/step - loss: 0.0350 - accuracy: 0.9910 - mse: 0.0065
# Epoch 39/60
# 8/8 [==============================] - 6s 685ms/step - loss: 0.0275 - accuracy: 1.0000 - mse: 0.0041
# Epoch 40/60
# 8/8 [==============================] - 6s 685ms/step - loss: 0.0221 - accuracy: 1.0000 - mse: 0.0026
# Epoch 41/60
# 8/8 [==============================] - 6s 688ms/step - loss: 0.0345 - accuracy: 0.9955 - mse: 0.0068
# Epoch 42/60
# 8/8 [==============================] - 8s 987ms/step - loss: 0.0232 - accuracy: 0.9955 - mse: 0.0043
# Epoch 43/60
# 8/8 [==============================] - 6s 691ms/step - loss: 0.0134 - accuracy: 1.0000 - mse: 0.0016
# Epoch 44/60
# 8/8 [==============================] - 6s 693ms/step - loss: 0.0221 - accuracy: 1.0000 - mse: 0.0029
# Epoch 45/60
# 8/8 [==============================] - 6s 692ms/step - loss: 0.0135 - accuracy: 1.0000 - mse: 0.0010
# Epoch 46/60
# 8/8 [==============================] - 6s 685ms/step - loss: 0.0105 - accuracy: 1.0000 - mse: 8.2311e-04
# Epoch 47/60
# 8/8 [==============================] - 6s 721ms/step - loss: 0.0063 - accuracy: 1.0000 - mse: 3.5475e-04
# Epoch 48/60
# 8/8 [==============================] - 8s 975ms/step - loss: 0.0053 - accuracy: 1.0000 - mse: 1.6584e-04
# Epoch 49/60
# 8/8 [==============================] - 6s 689ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 1.3433e-04
# Epoch 50/60
# 8/8 [==============================] - 6s 689ms/step - loss: 0.0048 - accuracy: 1.0000 - mse: 1.4781e-04
# Epoch 51/60
# 8/8 [==============================] - 6s 751ms/step - loss: 0.0032 - accuracy: 1.0000 - mse: 6.0062e-05
# Epoch 52/60
# 8/8 [==============================] - 6s 694ms/step - loss: 0.0036 - accuracy: 1.0000 - mse: 1.3789e-04
# Epoch 53/60
# 8/8 [==============================] - 6s 746ms/step - loss: 0.0039 - accuracy: 1.0000 - mse: 1.4333e-04
# Epoch 54/60
# 8/8 [==============================] - 6s 693ms/step - loss: 0.0027 - accuracy: 1.0000 - mse: 6.1719e-05
# Epoch 55/60
# 8/8 [==============================] - 6s 688ms/step - loss: 0.0031 - accuracy: 1.0000 - mse: 9.2594e-05
# Epoch 56/60
# 8/8 [==============================] - 6s 766ms/step - loss: 0.0028 - accuracy: 1.0000 - mse: 4.9447e-05
# Epoch 57/60
# 8/8 [==============================] - 6s 699ms/step - loss: 0.0029 - accuracy: 1.0000 - mse: 7.0883e-05
# Epoch 58/60
# 8/8 [==============================] - 6s 684ms/step - loss: 0.0026 - accuracy: 1.0000 - mse: 3.9278e-05
# Epoch 59/60
# 8/8 [==============================] - 6s 752ms/step - loss: 0.0023 - accuracy: 1.0000 - mse: 3.7074e-05
# Epoch 60/60
# 8/8 [==============================] - 6s 692ms/step - loss: 0.0020 - accuracy: 1.0000 - mse: 3.1032e-05

# %%
import numpy as np
import keras.utils as image

test_image = image.load_img('/content/drive/MyDrive/tentativa3/teste/h.6.jpg', target_size = (128, 128, 3))#, color_mode='grayscale')
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
training_set.class_indices

if result[0][0] == 1:
    prediction = 'Protozoario'
else:
    prediction = 'Helminto'

from IPython.display import Image

Image(filename='/content/drive/MyDrive/tentativa3/teste/h.6.jpg')

# %%
prediction
# Out:
# 'Protozoario'

# %%
import numpy as np
import keras.utils as image
import time
for x in range(0, 18):
  test_image = image.load_img('/content/drive/MyDrive/tentativa3/teste/h.'+f'{x+1}'+'.jpg', target_size = (128, 128, 3))#, color_mode='grayscale')
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis = 0)
  result = classifier.predict(test_image)
  training_set.class_indices

  if result[0][0] == 1:
      prediction = 'Protozoario'
  else:
      prediction = 'Helminto'
  time.sleep(1)
  print(f'{x+1}'+f' - {prediction}')
for x in range(0, 23):
  test_image = image.load_img('/content/drive/MyDrive/tentativa3/teste/p.'+f'{x+1}'+'.jpg', target_size = (128, 128, 3))#, color_mode='grayscale')
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis = 0)
  result = classifier.predict(test_image)
  training_set.class_indices
  if result[0][0] == 1:
      prediction = 'Protozoario'
  else:
      prediction = 'Helminto'
  time.sleep(1)
  print(f'{x+1}'+f' - {prediction}')
# Out:
# 1/1 [==============================] - 0s 184ms/step
# 1 - Helminto
# 1/1 [==============================] - 0s 50ms/step
# 2 - Helminto
# 1/1 [==============================] - 0s 109ms/step
# 3 - Helminto
# 1/1 [==============================] - 0s 32ms/step
# 4 - Helminto
# 1/1 [==============================] - 0s 30ms/step
# 5 - Helminto
# 1/1 [==============================] - 0s 43ms/step
# 6 - Helminto
# 1/1 [==============================] - 0s 36ms/step
# 7 - Protozoario
# 1/1 [==============================] - 0s 38ms/step
# 8 - Helminto
# 1/1 [==============================] - 0s 39ms/step
# 9 - Helminto
# 1/1 [==============================] - 0s 39ms/step
# 10 - Helminto
# 1/1 [==============================] - 0s 37ms/step
# 11 - Helminto
# 1/1 [==============================] - 0s 35ms/step
# 12 - Helminto
# 1/1 [==============================] - 0s 32ms/step
# 13 - Helminto
# 1/1 [==============================] - 0s 31ms/step
# 14 - Helminto
# 1/1 [==============================] - 0s 30ms/step
# 15 - Helminto
# 1/1 [==============================] - 0s 33ms/step
# 16 - Helminto
# 1/1 [==============================] - 0s 30ms/step
# 17 - Helminto
# 1/1 [==============================] - 0s 32ms/step
# 18 - Protozoario
# 1/1 [==============================] - 0s 33ms/step
# 1 - Protozoario
# 1/1 [==============================] - 0s 35ms/step
# 2 - Protozoario
# 1/1 [==============================] - 0s 31ms/step
# 3 - Protozoario
# 1/1 [==============================] - 0s 33ms/step
# 4 - Helminto
# 1/1 [==============================] - 0s 31ms/step
# 5 - Protozoario
# 1/1 [==============================] - 0s 29ms/step
# 6 - Protozoario
# 1/1 [==============================] - 0s 59ms/step
# 7 - Protozoario
# 1/1 [==============================] - 0s 30ms/step
# 8 - Helminto
# 1/1 [==============================] - 0s 30ms/step
# 9 - Protozoario
# 1/1 [==============================] - 0s 31ms/step
# 10 - Protozoario
# 1/1 [==============================] - 0s 31ms/step
# 11 - Helminto
# 1/1 [==============================] - 0s 32ms/step
# 12 - Helminto
# 1/1 [==============================] - 0s 33ms/step
# 13 - Protozoario
# 1/1 [==============================] - 0s 32ms/step
# 14 - Helminto
# 1/1 [==============================] - 0s 29ms/step
# 15 - Protozoario
# 1/1 [==============================] - 0s 30ms/step
# 16 - Protozoario
# 1/1 [==============================] - 0s 34ms/step
# 17 - Helminto
# 1/1 [==============================] - 0s 32ms/step
# 18 - Protozoario
# 1/1 [==============================] - 0s 30ms/step
# 19 - Protozoario
# 1/1 [==============================] - 0s 31ms/step
# 20 - Protozoario
# 1/1 [==============================] - 0s 30ms/step
# 21 - Protozoario
# 1/1 [==============================] - 0s 31ms/step
# 22 - Helminto
# 1/1 [==============================] - 0s 37ms/step
# 23 - Protozoario
